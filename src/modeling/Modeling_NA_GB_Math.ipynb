# %% [markdown]
# ## Experiment : Running Gradient Boosting for the raw data
# - Run 4 different Gradient Boosting models, CatBoost, XGBoost, LightGBM and HistGradientBoosting, for DATA_Texas_District_v3.csv specifying the indices of categorical features for models to handle them.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time

# import warnings 
# warnings.filterwarnings('ignore')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef, roc_auc_score

# %%
cols_drop=['County #', 'District #', 'r_all_d_g3_2019', 'r_ethh_d_g3_2019', 'r_etha_d_g3_2019', 'r_ethb_d_g3_2019', 'r_ethw_d_g3_2019', 'r_ecoy_d_g3_2019', 'r_eco1_d_g3_2019', 'r_ti1y_d_g3_2019', 'r_spey_d_g3_2019', 'r_all_d_g4_2019', 'r_ethh_d_g4_2019', 'r_etha_d_g4_2019', 'r_ethb_d_g4_2019', 'r_ethw_d_g4_2019', 'r_ecoy_d_g4_2019', 'r_eco1_d_g4_2019', 'r_ti1y_d_g4_2019', 'r_spey_d_g4_2019', 'r_all_d_g5_2019', 'r_ethh_d_g5_2019', 'r_etha_d_g5_2019', 'r_ethb_d_g5_2019', 'r_ethw_d_g5_2019', 'r_ecoy_d_g5_2019', 'r_eco1_d_g5_2019', 'r_ti1y_d_g5_2019', 'r_spey_d_g5_2019', 'r_all_d_g6_2019', 'r_ethh_d_g6_2019', 'r_etha_d_g6_2019', 'r_ethb_d_g6_2019', 'r_ethw_d_g6_2019', 'r_ecoy_d_g6_2019', 'r_eco1_d_g6_2019', 'r_ti1y_d_g6_2019', 'r_spey_d_g6_2019', 'r_all_d_g7_2019', 'r_ethh_d_g7_2019', 'r_etha_d_g7_2019', 'r_ethb_d_g7_2019', 'r_ethw_d_g7_2019', 'r_ecoy_d_g7_2019', 'r_eco1_d_g7_2019', 'r_ti1y_d_g7_2019', 'r_spey_d_g7_2019', 'r_all_d_g8_2019', 'r_ethh_d_g8_2019', 'r_etha_d_g8_2019', 'r_ethb_d_g8_2019', 'r_ethw_d_g8_2019', 'r_ecoy_d_g8_2019', 'r_eco1_d_g8_2019', 'r_ti1y_d_g8_2019', 'r_spey_d_g8_2019', 'r_all_d_g3_2021', 'r_ethh_d_g3_2021', 'r_etha_d_g3_2021', 'r_ethb_d_g3_2021', 'r_ethw_d_g3_2021', 'r_ecoy_d_g3_2021', 'r_eco1_d_g3_2021', 'r_ti1y_d_g3_2021', 'r_spey_d_g3_2021', 'r_all_d_g4_2021', 'r_ethh_d_g4_2021', 'r_etha_d_g4_2021', 'r_ethb_d_g4_2021', 'r_ethw_d_g4_2021', 'r_ecoy_d_g4_2021', 'r_eco1_d_g4_2021', 'r_ti1y_d_g4_2021', 'r_spey_d_g4_2021', 'r_all_d_g5_2021', 'r_ethh_d_g5_2021', 'r_etha_d_g5_2021', 'r_ethb_d_g5_2021', 'r_ethw_d_g5_2021', 'r_ecoy_d_g5_2021', 'r_eco1_d_g5_2021', 'r_ti1y_d_g5_2021', 'r_spey_d_g5_2021', 'r_all_d_g6_2021', 'r_ethh_d_g6_2021', 'r_etha_d_g6_2021', 'r_ethb_d_g6_2021', 'r_ethw_d_g6_2021', 'r_ecoy_d_g6_2021', 'r_eco1_d_g6_2021', 'r_ti1y_d_g6_2021', 'r_spey_d_g6_2021', 'r_all_d_g
4_2021', 'm_all_d_g5_2021', 'm_ethh_d_g5_2021', 'm_etha_d_g5_2021', 'm_ethb_d_g5_2021', 'm_ethw_d_g5_2021', 'm_ecoy_d_g5_2021', 'm_eco1_d_g5_2021', 'm_ti1y_d_g5_2021', 'm_spey_d_g5_2021', 'm_all_d_g6_2021', 'm_ethh_d_g6_2021', 'm_etha_d_g6_2021', 'm_ethb_d_g6_2021', 'm_ethw_d_g6_2021', 'm_ecoy_d_g6_2021', 'm_eco1_d_g6_2021', 'm_ti1y_d_g6_2021', 'm_spey_d_g6_2021', 'm_all_d_g7_2021', 'm_ethh_d_g7_2021', 'm_etha_d_g7_2021', 'm_ethb_d_g7_2021', 'm_ethw_d_g7_2021', 'm_ecoy_d_g7_2021', 'm_eco1_d_g7_2021', 'm_ti1y_d_g7_2021', 'm_spey_d_g7_2021', 'm_all_d_g8_2021', 'm_ethh_d_g8_2021', 'm_etha_d_g8_2021', 'm_ethb_d_g8_2021', 'm_ethw_d_g8_2021', 'm_ecoy_d_g8_2021', 'm_eco1_d_g8_2021', 'm_ti1y_d_g8_2021', 'm_spey_d_g8_2021', 'District Enrollment 09/28/20', 'Approx. District On-Campus Enrollment 09/28/20']

# %% [markdown]
# ### Prepare data ###

# %% [markdown]
# Loading the data cleaned from [Data_Integration.ipynb](../processing/Data_Integration.ipynb)

# %%
df = pd.read_csv('../processing/DATA_Texas_District_v3.csv', sep=',', header=0)
print('Shape before dropping reading columns:',df.shape)
df.drop(columns=cols_drop, inplace=True)
print('Shape after dropping reading columns:',df.shape)
# Out:
# Shape before dropping reading columns: (1165, 511)
# Shape after dropping reading columns: (1165, 305)

# %% [markdown]
# Make values for label as a postive integer as some models cannot process negative class.

# %%
df['Label'] = df['Label_Math'].apply(lambda x: 0 if x == -1
                                                 else 1 if x == 0
                                                 else 2)

# %% [markdown]
# **Encoding**
#
# Experimenting grandient boosting models for data with missing values:
#
# - **0**: no imputing, missing values are np.nan
# - **1**: impute for missing values

# %%
def encoding (df, ver):
    
    # convert only categorical feature 'Locale' into integer values
    categorical_cols = ['Locale']
    df['Locale']=df['Locale'].apply(lambda x: int(x[:2]))

    if ver == 0: return df, categorical_cols

    imp_avg = SimpleImputer(missing_values=np.nan, strategy='mean')
    
    df[cols_imp] = imp_avg.fit_transform(df[cols_imp]) 
    
    return df, categorical_cols

# %% [markdown]
# **Split data**

# %%
random_state=123

# %%
def split_data (df):
    labels = ['Label_Math', 'Label_Reading', 'Label_All']

    y = df['Label'].values.ravel()
    X = df.drop(columns=labels + ['Label'])
    columns = df.drop(columns=labels + ['Label']).columns.to_list()

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y,
                                                    random_state=random_state, shuffle=True)
    
    return X_train, X_test, y_train, y_test, columns

# %% [markdown]
# **n iteration for models**

# %%
def get_n_iter (param_grid):
    n_iter_ratio = 0.2
    n_iter = 1
    for v in param_grid.values(): n_iter*=len(v)
    n_iter *= n_iter_ratio

    return int(n_iter)

# %% [markdown]
# ### Modeling

# %%
encoding_type=['No Impute', 'Impute']
rounds = 20

# %%
def model_report(estimator, param_grid, fit_params, name):
    result = pd.DataFrame()
    avg = 'weighted'
    cv=5

    n_iter=get_n_iter(param_grid)
    print('{} n_iter: {:0.0f}'.format(name, n_iter))
    if name == 'CatBoost': n_iter=100
       
    for enc_ver in range(len(encoding_type)):
        df_copy, categorical_cols = encoding(df.copy(), enc_ver)
        X_train, X_test, y_train, y_test, columns = split_data(df_copy) 
        
        categorical_cols_idx = [columns.index(c) for c in categorical_cols]    

        if len(categorical_cols) > 0:
            if (name == 'LightGBM'): fit_params['categorical_feature']=categorical_cols_idx
            if (name == 'CatBoost'): fit_params['cat_features']=categorical_cols_idx
            if (name == 'HistGB'): estimator.set_params(**{'categorical_features': categorical_cols_idx})
            if (name == 'XGBoost'):
                X_train=pd.concat([X_train[c].astype('category') if c in categorical_cols else X_train[c] for c in X_train.columns], axis=1)
                X_test=pd.concat([X_test[c].astype('category') if c in categorical_cols else X_test[c] for c in X_test.columns], axis=1)
        else:
            if (name == 'LightGBM'): fit_params['categorical_feature']=None
            if (name == 'CatBoost'): fit_params['cat_features']=None
            if (name == 'HistGB'): estimator.set_params(**{'categorical_features': None})
        
        grid = RandomizedSearchCV(estimator, param_distributions=param_grid, cv=cv, n_jobs=-1, 
                            random_state=random_state, n_iter=n_iter)

        start_cpu = time.process_time()
        start_wall = time.time()
         
        if name == 'HistGB': 
            grid.fit(X_train, y_train)
        else:
            fit_params['eval_set'] =  [(X_test, y_test)]
            grid.fit(X_train, y_train, **fit_params)
            
        if name == 'XGBoost': grid.best_estimator_.save_model("categorical-model.json") 

        cpu_time = time.process_time() - start_cpu
        wall_time = time.time() - start_wall
        y_pred = grid.best_estimator_.predict(X_test)

        temp = {'Model': name,
                'enc_ver': encoding_type[enc_ver],
                'n features': len(columns),
                'n cat_features': len(categorical_cols),
                'best_params': grid.best_params_,
                'Best Accuracy': grid.best_score_, 
                'Train Accuracy': grid.best_estimator_.score(X_train, y_train),
                'Test Accuracy': accuracy_score(y_test, y_pred),
                'Precision': precision_score(y_test, y_pred, average=avg),
                'Recall': recall_score(y_test, y_pred, average=avg),
                'MCC': matthews_corrcoef(y_test, y_pred), 
                'F1': f1_score(y_test, y_pred, average=avg),
    #                 'ROC': roc_auc_score(y_test, grid.best_estimator_.predict_proba(X_test), multi_class='ovr', average=avg),
                'conf_mat': confusion_matrix(y_test, y_pred), 
                'Prediction': y_pred,
                'predict_proba': grid.best_estimator_.predict_proba(X_test),
    #             'Features': features,
                'estimator': grid.best_estimator_,
                'classification_report': classification_report(y_test, y_pred),
                'Train Time CPU': cpu_time,
                'Train Time Wall': wall_time,
                'n_iter': n_iter}
        result = pd.concat([result, pd.DataFrame([temp])], ignore_index=True)
    return result

# %%
results = pd.DataFrame()

# %% [markdown]
# **CatBoost**

# %%
# %%time
from catboost import CatBoostClassifier

params = {'iterations': [50, 100, 200],
'depth': [3, 6, 9],
'min_data_in_leaf': [1, 5, 10],
'learning_rate': [0.01, 0.1, 0.2, 0.3],
'l2_leaf_reg': [0, 0.01, 0.1, 1, 10],
'random_strength': [0, 5, 10, 15]}

fit_params = {'early_stopping_rounds': rounds}

estimator = CatBoostClassifier(random_seed=random_state, verbose=False, 
                               loss_function='MultiClass', eval_metric="MultiClass", one_hot_max_size=4, border_count=254)
                           
result_report=model_report(estimator, params, fit_params, 'CatBoost')
results=pd.concat([results, result_report], ignore_index=True)
# Out:
# CatBoost n_iter: 432
# CPU times: total: 1min 22s
# Wall time: 3h 39min 35s

# %% [markdown]
# **XGBoost**

# %%
# %%time
import xgboost

params = {'n_estimators': [50, 100, 200],
'max_depth': [1, 6, 0],
'min_child_weight': [0, 0.001, 0.1, 1],
'learning_rate': [0.01, 0.1, 0.2, 0.3],
'alpha': [0,  0.1, 10],
'lambda': [0,  0.1, 10],
'gamma': [0,  0.1, 10]}


estimator = xgboost.XGBClassifier(seed=random_state, objective='multi:softproba', eval_metric='mlogloss', use_label_encoder=False, verbosity=0,
                                  num_class=3, tree_method="hist", early_stopping_rounds=rounds, enable_categorical=True, max_cat_to_onehot=4)


result_report=model_report(estimator, params, {}, 'XGBoost')
results=pd.concat([results, result_report], ignore_index=True)
# Out:
# XGBoost n_iter: 777
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# ...
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\xgboost\data.py:322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   transformed[data.columns[i]] = data[data.columns[i]]

# %% [markdown]
# **LightGBM**

# %%
# %%time
import lightgbm as lgb

params = {'n_estimators': [50, 100, 200],
'max_depth': [1, 6, -1],
'min_sum_hessian_in_leaf': [0, 0.001, 0.1, 1],
'learning_rate': [0.01, 0.1, 0.2, 0.3],
'reg_alpha': [0,  0.1, 10],
'reg_lambda': [0,  0.1, 10],
'min_split_gain': [0,  0.1, 10]}

fit_params = {'early_stopping_rounds': rounds}

estimator = lgb.LGBMClassifier(random_state=random_state, objective="multiclass", metric="multi_logloss", verbosity=-1, silent=True, force_col_wise=True,
                               num_class=3, is_unbalance=True, max_cat_threshold=32)

result_report=model_report(estimator, params, fit_params, 'LightGBM')
results=pd.concat([results, result_report], ignore_index=True)
# Out:
# LightGBM n_iter: 777
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 3 fits failed out of a total of 3885.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\lightgbm\sklearn.py", line 890, in fit
#     super().fit(X, _y, sample_weight=sample_weight, init_score=init_score, eval_set=valid_sets,
#   File "C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\lightgbm\sklearn.py", line 683, in fit
#     self._Booster = train(params, train_set,
#   File "C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\lightgbm\engine.py", line 249, in train
#     booster.update(fobj=fobj)
#   File "C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\lightgbm\basic.py", line 2643, in update
#     _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#   File "C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\lightgbm\basic.py", line 110, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode('utf-8'))
# lightgbm.basic.LightGBMError: Check failed: (best_split_info.left_count) > (0) at c:\users\builder\appdata\local\temp\pip-req-build-yqorhuc_\compile\src\treelearner\serial_tree_learner.cpp, line 653 .
#
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.71455925 0.67058824 0.67809787 0.71137945 0.67486631 0.70170778
#  0.69098384 0.72532344 0.57829912 0.6942154  0.71032143 0.63191881
#  0.68776954 0.69636594 0.66092807 0.69527917 0.57829912 0.53535737
#  0.67595883 0.69206486 0.69636594 0.56219884 0.71027543 0.67595883
#  0.66626991 0.71459376 0.72425967 0.72212064 0.66951872 0.6083319
#  0.53967569 0.6544707  0.63945719 0.66092807 0.53535737 0.67380829
#  0.61046518 0.61045368 0.60512909 0.65018113 0.714565   0.72535219
#  0.68345121 0.63517337 0.68131217 0.72316141 0.67381979 0.64374102
#  0.69529642 0.59974125 0.68023115 0.67810362 0.68023115 0.5515094
#  0.73068829 0.71463401 0.65877753 0.65664424 0.65664424 0.59226036
#  0.68131217 0.65877753 0.72425392 0.71890633 0.72747398 0.63945144
#  0.66629866 0.68346846 0.69098384 0.73286758 0.56543615 0.65877753
#  0.6083319  0.66628141 0.53535737 0.67810362 0.65877753 0.63838192
# [14]	valid_0's multi_logloss: 0.699807
# [15]	valid_0's multi_logloss: 0.68969
# [16]	valid_0's multi_logloss: 0.684872
# [17]	valid_0's multi_logloss: 0.673754
# [18]	valid_0's multi_logloss: 0.672272
# [19]	valid_0's multi_logloss: 0.664884
# [20]	valid_0's multi_logloss: 0.655856
# [21]	valid_0's multi_logloss: 0.652961
# [22]	valid_0's multi_logloss: 0.649451
# [23]	valid_0's multi_logloss: 0.647218
# [24]	valid_0's multi_logloss: 0.641337
# [25]	valid_0's multi_logloss: 0.63813
# [26]	valid_0's multi_logloss: 0.63706
# [27]	valid_0's multi_logloss: 0.63668
# [28]	valid_0's multi_logloss: 0.631805
# [29]	valid_0's multi_logloss: 0.625976
# [30]	valid_0's multi_logloss: 0.626451
# [31]	valid_0's multi_logloss: 0.622805
# [32]	valid_0's multi_logloss: 0.622699
# [33]	valid_0's multi_logloss: 0.622438
# [34]	valid_0's multi_logloss: 0.616595
# [35]	valid_0's multi_logloss: 0.615957
# [36]	valid_0's multi_logloss: 0.615884
# [37]	valid_0's multi_logloss: 0.613066
# [38]	valid_0's multi_logloss: 0.614938
# [39]	valid_0's multi_logloss: 0.606847
# [40]	valid_0's multi_logloss: 0.607454
# [41]	valid_0's multi_logloss: 0.607609
# [42]	valid_0's multi_logloss: 0.609578
# [43]	valid_0's multi_logloss: 0.608116
# [44]	valid_0's multi_logloss: 0.608315
# [45]	valid_0's multi_logloss: 0.605559
# [46]	valid_0's multi_logloss: 0.605141
# [47]	valid_0's multi_logloss: 0.605496
# [48]	valid_0's multi_logloss: 0.606103
# [49]	valid_0's multi_logloss: 0.606515
# [50]	valid_0's multi_logloss: 0.606263
# [51]	valid_0's multi_logloss: 0.605152
# [52]	valid_0's multi_logloss: 0.601658
# [53]	valid_0's multi_logloss: 0.600891
# [54]	valid_0's multi_logloss: 0.599757
# [55]	valid_0's multi_logloss: 0.599493
# [56]	valid_0's multi_logloss: 0.601446
# [57]	valid_0's multi_logloss: 0.602633
# [58]	valid_0's multi_logloss: 0.602978
# [59]	valid_0's multi_logloss: 0.602435
# [60]	valid_0's multi_logloss: 0.603629
# [61]	valid_0's multi_logloss: 0.602682
# [62]	valid_0's multi_logloss: 0.600874
# [63]	valid_0's multi_logloss: 0.599072
# [64]	valid_0's multi_logloss: 0.600689
# [65]	valid_0's multi_logloss: 0.600319
# [66]	valid_0's multi_logloss: 0.599346
# [67]	valid_0's multi_logloss: 0.59862
# [68]	valid_0's multi_logloss: 0.598869
# [69]	valid_0's multi_logloss: 0.599086
# [70]	valid_0's multi_logloss: 0.59842
# [71]	valid_0's multi_logloss: 0.598897
# [72]	valid_0's multi_logloss: 0.599575
# [73]	valid_0's multi_logloss: 0.59857
# [74]	valid_0's multi_logloss: 0.59791
# [75]	valid_0's multi_logloss: 0.595869
# [76]	valid_0's multi_logloss: 0.595461
# [77]	valid_0's multi_logloss: 0.595619
# [78]	valid_0's multi_logloss: 0.595554
# [79]	valid_0's multi_logloss: 0.595829
# [80]	valid_0's multi_logloss: 0.595582
# [81]	valid_0's multi_logloss: 0.596405
# [82]	valid_0's multi_logloss: 0.597584
# [83]	valid_0's multi_logloss: 0.59704
# [84]	valid_0's multi_logloss: 0.596838
# [85]	valid_0's multi_logloss: 0.595603
# [86]	valid_0's multi_logloss: 0.594938
# [87]	valid_0's multi_logloss: 0.594902
# [88]	valid_0's multi_logloss: 0.59434
# [89]	valid_0's multi_logloss: 0.595042
# [90]	valid_0's multi_logloss: 0.59497
# [91]	valid_0's multi_logloss: 0.595012
# [92]	valid_0's multi_logloss: 0.595769
# [93]	valid_0's multi_logloss: 0.596097
# [94]	valid_0's multi_logloss: 0.596138
# [95]	valid_0's multi_logloss: 0.596534
# [96]	valid_0's multi_logloss: 0.596002
# [97]	valid_0's multi_logloss: 0.595653
# [98]	valid_0's multi_logloss: 0.595385
# [99]	valid_0's multi_logloss: 0.595885
# [100]	valid_0's multi_logloss: 0.595176
# Did not meet early stopping. Best iteration is:
# [88]	valid_0's multi_logloss: 0.59434
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=0.001, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=0.001
# [1]	valid_0's multi_logloss: 0.992666
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's multi_logloss: 0.947877
# [3]	valid_0's multi_logloss: 0.928967
# [4]	valid_0's multi_logloss: 0.905244
# [5]	valid_0's multi_logloss: 0.888567
# [6]	valid_0's multi_logloss: 0.882233
# [7]	valid_0's multi_logloss: 0.867635
# [8]	valid_0's multi_logloss: 0.85897
# [9]	valid_0's multi_logloss: 0.855753
# [10]	valid_0's multi_logloss: 0.845632
# [11]	valid_0's multi_logloss: 0.845025
# [12]	valid_0's multi_logloss: 0.840229
# [13]	valid_0's multi_logloss: 0.836306
# [14]	valid_0's multi_logloss: 0.831966
# [15]	valid_0's multi_logloss: 0.820985
# [16]	valid_0's multi_logloss: 0.819657
# [17]	valid_0's multi_logloss: 0.819648
# [18]	valid_0's multi_logloss: 0.815729
# [19]	valid_0's multi_logloss: 0.810337
# [20]	valid_0's multi_logloss: 0.809729
# [21]	valid_0's multi_logloss: 0.808517
# [22]	valid_0's multi_logloss: 0.80756
# [23]	valid_0's multi_logloss: 0.801034
# [24]	valid_0's multi_logloss: 0.794856
# [25]	valid_0's multi_logloss: 0.789782
# [26]	valid_0's multi_logloss: 0.786642
# [27]	valid_0's multi_logloss: 0.786947
# [28]	valid_0's multi_logloss: 0.782423
# [29]	valid_0's multi_logloss: 0.775775
# [30]	valid_0's multi_logloss: 0.772203
# [31]	valid_0's multi_logloss: 0.769958
# [32]	valid_0's multi_logloss: 0.767677
# [33]	valid_0's multi_logloss: 0.767654
# [34]	valid_0's multi_logloss: 0.764075
# [35]	valid_0's multi_logloss: 0.759464
# [36]	valid_0's multi_logloss: 0.755788
# [37]	valid_0's multi_logloss: 0.754562
# [38]	valid_0's multi_logloss: 0.750221
# [39]	valid_0's multi_logloss: 0.746783
# [40]	valid_0's multi_logloss: 0.743631
# [41]	valid_0's multi_logloss: 0.741305
# [42]	valid_0's multi_logloss: 0.737238
# [43]	valid_0's multi_logloss: 0.734489
# [44]	valid_0's multi_logloss: 0.732785
# [45]	valid_0's multi_logloss: 0.733865
# [46]	valid_0's multi_logloss: 0.728433
# [47]	valid_0's multi_logloss: 0.732097
# [48]	valid_0's multi_logloss: 0.728914
# [49]	valid_0's multi_logloss: 0.729331
# [50]	valid_0's multi_logloss: 0.72528
# [51]	valid_0's multi_logloss: 0.724973
# [52]	valid_0's multi_logloss: 0.722948
# [53]	valid_0's multi_logloss: 0.717783
# [54]	valid_0's multi_logloss: 0.717207
# [55]	valid_0's multi_logloss: 0.715079
# [56]	valid_0's multi_logloss: 0.710375
# [57]	valid_0's multi_logloss: 0.711166
# [58]	valid_0's multi_logloss: 0.709425
# [59]	valid_0's multi_logloss: 0.706495
# [60]	valid_0's multi_logloss: 0.706236
# [61]	valid_0's multi_logloss: 0.705015
# [62]	valid_0's multi_logloss: 0.704909
# [63]	valid_0's multi_logloss: 0.701504
# [64]	valid_0's multi_logloss: 0.697609
# [65]	valid_0's multi_logloss: 0.692487
# [66]	valid_0's multi_logloss: 0.688798
# [67]	valid_0's multi_logloss: 0.691253
# [68]	valid_0's multi_logloss: 0.692045
# [69]	valid_0's multi_logloss: 0.691345
# [70]	valid_0's multi_logloss: 0.690356
# [71]	valid_0's multi_logloss: 0.690186
# [72]	valid_0's multi_logloss: 0.691434
# [73]	valid_0's multi_logloss: 0.691508
# [74]	valid_0's multi_logloss: 0.691437
# [75]	valid_0's multi_logloss: 0.689842
# [76]	valid_0's multi_logloss: 0.687714
# [77]	valid_0's multi_logloss: 0.68478
# [78]	valid_0's multi_logloss: 0.684321
# [79]	valid_0's multi_logloss: 0.687984
# [80]	valid_0's multi_logloss: 0.686123
# [81]	valid_0's multi_logloss: 0.684162
# [82]	valid_0's multi_logloss: 0.682926
# [83]	valid_0's multi_logloss: 0.685075
# [84]	valid_0's multi_logloss: 0.684185
# [85]	valid_0's multi_logloss: 0.684796
# [86]	valid_0's multi_logloss: 0.682378
# [87]	valid_0's multi_logloss: 0.682578
# [88]	valid_0's multi_logloss: 0.681348
# [89]	valid_0's multi_logloss: 0.679265
# [90]	valid_0's multi_logloss: 0.679898
# [91]	valid_0's multi_logloss: 0.680689
# [92]	valid_0's multi_logloss: 0.679378
# [93]	valid_0's multi_logloss: 0.677086
# [94]	valid_0's multi_logloss: 0.674213
# [95]	valid_0's multi_logloss: 0.676278
# [96]	valid_0's multi_logloss: 0.674411
# [97]	valid_0's multi_logloss: 0.674022
# [98]	valid_0's multi_logloss: 0.673183
# [99]	valid_0's multi_logloss: 0.672111
# [100]	valid_0's multi_logloss: 0.674313
# [101]	valid_0's multi_logloss: 0.673084
# [102]	valid_0's multi_logloss: 0.672231
# [103]	valid_0's multi_logloss: 0.672147
# [104]	valid_0's multi_logloss: 0.672925
# [105]	valid_0's multi_logloss: 0.671603
# [106]	valid_0's multi_logloss: 0.672631
# [107]	valid_0's multi_logloss: 0.67105
# [108]	valid_0's multi_logloss: 0.668915
# [109]	valid_0's multi_logloss: 0.666638
# [110]	valid_0's multi_logloss: 0.667921
# [111]	valid_0's multi_logloss: 0.66606
# [112]	valid_0's multi_logloss: 0.667048
# [113]	valid_0's multi_logloss: 0.666682
# [114]	valid_0's multi_logloss: 0.665676
# [115]	valid_0's multi_logloss: 0.66486
# [116]	valid_0's multi_logloss: 0.663861
# [117]	valid_0's multi_logloss: 0.663507
# [118]	valid_0's multi_logloss: 0.66131
# [119]	valid_0's multi_logloss: 0.661953
# [120]	valid_0's multi_logloss: 0.660513
# [121]	valid_0's multi_logloss: 0.657561
# [122]	valid_0's multi_logloss: 0.656559
# [123]	valid_0's multi_logloss: 0.655661
# [124]	valid_0's multi_logloss: 0.655868
# [125]	valid_0's multi_logloss: 0.654226
# [126]	valid_0's multi_logloss: 0.654608
# [127]	valid_0's multi_logloss: 0.653698
# [128]	valid_0's multi_logloss: 0.652295
# [129]	valid_0's multi_logloss: 0.653477
# [130]	valid_0's multi_logloss: 0.65025
# [131]	valid_0's multi_logloss: 0.651102
# [132]	valid_0's multi_logloss: 0.649635
# [133]	valid_0's multi_logloss: 0.652459
# [134]	valid_0's multi_logloss: 0.650742
# [135]	valid_0's multi_logloss: 0.649406
# [136]	valid_0's multi_logloss: 0.648549
# [137]	valid_0's multi_logloss: 0.6495
# [138]	valid_0's multi_logloss: 0.647476
# [139]	valid_0's multi_logloss: 0.648662
# [140]	valid_0's multi_logloss: 0.648336
# [141]	valid_0's multi_logloss: 0.647532
# [142]	valid_0's multi_logloss: 0.649413
# [143]	valid_0's multi_logloss: 0.648716
# [144]	valid_0's multi_logloss: 0.650624
# [145]	valid_0's multi_logloss: 0.650338
# [146]	valid_0's multi_logloss: 0.649639
# [147]	valid_0's multi_logloss: 0.648448
# [148]	valid_0's multi_logloss: 0.649503
# [149]	valid_0's multi_logloss: 0.648315
# [150]	valid_0's multi_logloss: 0.647896
# [151]	valid_0's multi_logloss: 0.646559
# [152]	valid_0's multi_logloss: 0.644055
# [153]	valid_0's multi_logloss: 0.645714
# [154]	valid_0's multi_logloss: 0.644296
# [155]	valid_0's multi_logloss: 0.64375
# [156]	valid_0's multi_logloss: 0.642832
# [157]	valid_0's multi_logloss: 0.63919
# [158]	valid_0's multi_logloss: 0.639875
# [159]	valid_0's multi_logloss: 0.639251
# [160]	valid_0's multi_logloss: 0.638964
# [161]	valid_0's multi_logloss: 0.636864
# [162]	valid_0's multi_logloss: 0.639704
# [163]	valid_0's multi_logloss: 0.6372
# [164]	valid_0's multi_logloss: 0.632378
# [165]	valid_0's multi_logloss: 0.631034
# [166]	valid_0's multi_logloss: 0.633117
# [167]	valid_0's multi_logloss: 0.631758
# [168]	valid_0's multi_logloss: 0.630493
# [169]	valid_0's multi_logloss: 0.630548
# [170]	valid_0's multi_logloss: 0.631231
# [171]	valid_0's multi_logloss: 0.633186
# [172]	valid_0's multi_logloss: 0.633222
# [173]	valid_0's multi_logloss: 0.634969
# [174]	valid_0's multi_logloss: 0.634301
# [175]	valid_0's multi_logloss: 0.632638
# [176]	valid_0's multi_logloss: 0.633035
# [177]	valid_0's multi_logloss: 0.632928
# [178]	valid_0's multi_logloss: 0.633778
# [179]	valid_0's multi_logloss: 0.632062
# [180]	valid_0's multi_logloss: 0.631795
# [181]	valid_0's multi_logloss: 0.631443
# [182]	valid_0's multi_logloss: 0.633617
# [183]	valid_0's multi_logloss: 0.631887
# [184]	valid_0's multi_logloss: 0.632352
# [185]	valid_0's multi_logloss: 0.633252
# [186]	valid_0's multi_logloss: 0.633264
# [187]	valid_0's multi_logloss: 0.632555
# [188]	valid_0's multi_logloss: 0.631243
# Early stopping, best iteration is:
# [168]	valid_0's multi_logloss: 0.630493
# CPU times: total: 43.7 s
# Wall time: 12min 43s
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\lightgbm\basic.py:1702: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\lightgbm\basic.py:1705: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [10]
#   _log_warning('categorical_feature in Dataset is overridden.\n'
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\lightgbm\basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\PC3\anaconda3\envs\ML310\lib\site-packages\lightgbm\basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))

# %% [markdown]
# **HistGradientBoosting**

# %%
# %%time
from sklearn.ensemble import HistGradientBoostingClassifier

params = {'max_iter': [50, 100, 200],
'max_depth': [1, 6, None],
'max_leaf_nodes': [10, 31, 50, 64],
'min_samples_leaf': [10, 20, 30],
'learning_rate': [0.01, 0.1, 0.2, 0.3],
'l2_regularization': [0, 0.01, 0.1, 1, 10]}

estimator=HistGradientBoostingClassifier(random_state=random_state, n_iter_no_change=rounds, early_stopping=True)

result_report=model_report(estimator, params, {}, 'HistGB')
results=pd.concat([results, result_report], ignore_index=True)
# Out:
# HistGB n_iter: 432
# CPU times: total: 1min 21s
# Wall time: 1h 1min 15s

# %%
results.to_csv('NA_Modeling_GB_Math.csv', index=False)

# %% [markdown]
# ## Result ##

# %%
results.sort_values(by=['MCC', 'F1'], ascending=False).head(10)[['Model', 'enc_ver', 'n features', 'n cat_features', 'Test Accuracy', 'Precision', 'Recall', 'MCC', 'F1', 'best_params']]
# Out:
#       Model    enc_ver  n features  n cat_features  Test Accuracy  Precision  \
# 0  CatBoost  No Impute         302               1       0.721030   0.720099
# 4  LightGBM  No Impute         302               1       0.712446   0.715892
# 5  LightGBM     Impute         302               1       0.708155   0.707987
# 6    HistGB  No Impute         302               1       0.703863   0.705257
# 1  CatBoost     Impute         302               1       0.699571   0.697550
# 2   XGBoost  No Impute         302               1       0.695279   0.693686
# 3   XGBoost     Impute         302               1       0.682403   0.679977
# 7    HistGB     Impute         302               1       0.686695   0.687075
#
#      Recall       MCC        F1  \
# 0  0.721030  0.543621  0.717149
# 4  0.712446  0.531900  0.712004
# 5  0.708155  0.527096  0.707411
# 6  0.703863  0.515211  0.700802
# 1  0.699571  0.504844  0.689585
# 2  0.695279  0.500837  0.691228
# 3  0.682403  0.484542  0.680390
# 7  0.686695  0.484258  0.681312
#
#                                          best_params
# 0  {'random_strength': 0, 'min_data_in_leaf': 5, ...
# 4  {'reg_lambda': 10, 'reg_alpha': 0.1, 'n_estima...
# 5  {'reg_lambda': 0.1, 'reg_alpha': 0.1, 'n_estim...
# 6  {'min_samples_leaf': 30, 'max_leaf_nodes': 50,...
# 1  {'random_strength': 0, 'min_data_in_leaf': 5, ...
# 2  {'n_estimators': 200, 'min_child_weight': 1, '...
# 3  {'n_estimators': 200, 'min_child_weight': 0.00...
# 7  {'min_samples_leaf': 20, 'max_leaf_nodes': 50,...

# %% [markdown]
# **Accuracy, MCC and F1 Score**

# %%
results2 = pd.DataFrame()
for col in ['Train Accuracy', 'Test Accuracy', 'MCC', 'F1']:
    temp = results[['Model', 'enc_ver'] + [col]].copy()
    temp['Score'] = col
    temp.rename(columns={col: 'Score value'}, inplace=True)
    results2 = pd.concat([results2, temp], ignore_index=True)
# results2=results2.astype({'n Selected': 'int32'})

# %%
sns.set(rc={'figure.figsize':(20,20)})
sns.set_theme(style='whitegrid')
sns.set(font_scale=1.8)

g = sns.catplot(x="enc_ver", y="Score value", hue="Score", col="Model",
                capsize=.2, palette="magma", height=6, aspect=.75,
                kind="point", data=results2)
g.despine(left=True)
plt.show()

# %%
models = results['Model'].unique().tolist()
temp=results.sort_values(by=['Model', 'MCC', 'F1'], ascending=False)

n=len(encoding_type)
best_per_model_idx = []
for i in range(len(temp.index)):
    if i % n == 0: best_per_model_idx.append(temp.index[i])

# %% [markdown]
# **Confusion Matrix**

# %%
from mlxtend.plotting import plot_confusion_matrix
import matplotlib.ticker as mticker

def ticks(x, position):
    if position == 1: return 'Loss'
    if position == 2: return 'Exp'
    if position == 3: return 'Gain'
    
fig, axes=plt.subplots(1,len(best_per_model_idx), figsize=(20,10))
sns.set(font_scale=1.2)

for idx, i in zip(sorted(best_per_model_idx), range(len(best_per_model_idx))):
    plot_confusion_matrix(axis=axes[i], conf_mat=results.loc[idx, 'conf_mat'],
                          show_absolute=True, show_normed=True)
    title='{}-{}'.format(results.loc[idx, 'Model'], results.loc[idx, 'enc_ver'])
    axes[i].set_title(title, fontsize=20)
    if (i > 0): axes[i].set(xlabel='', ylabel='')
    else : axes[i].set(xlabel='Predicted Label', ylabel='True Label')
    axes[i].xaxis.set_major_formatter(mticker.FuncFormatter(ticks))
    axes[i].yaxis.set_major_formatter(mticker.FuncFormatter(ticks))
plt.show()

# %% [markdown]
# **ROC Curve**

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

X_train, X_test, y_train, y_test, columns = split_data(df.copy()) 
classes=[0, 1, 2]
y_test_bin=label_binarize(y_test, classes=classes)

fig, axes=plt.subplots(1,len(best_per_model_idx), figsize=(20,5))
sns.set(font_scale=1)

for idx, i in zip(sorted(best_per_model_idx), range(len(best_per_model_idx))):
    fpr, tpr = {}, {}

    for c in classes:
        fpr[c], tpr[c], _ = roc_curve(y_test_bin[:, c], results.loc[idx, 'predict_proba'][:, c])
        axes[i].plot(fpr[c], tpr[c], lw=2, label='{} (AUC={:0.2f})'.format(ticks(c,c+1), auc(fpr[c], tpr[c])))
    
    title='{}-{}'.format(results.loc[idx, 'Model'], results.loc[idx, 'enc_ver'])
    axes[i].set_title(title, fontsize=20)
    axes[i].set_xlabel("False Postive Rate")
    axes[0].set_ylabel("True Positive Rate")
    axes[i].legend(loc="best")

plt.show()

# %% [markdown]
# **Precision-Recall Curve**

# %%
### from sklearn.preprocessing import label_binarize
from sklearn.metrics import precision_recall_curve

X_train, X_test, y_train, y_test, columns = split_data(df.copy()) 
classes=[0, 1, 2]
y_test_bin=label_binarize(y_test, classes=classes)

fig, axes=plt.subplots(1,len(best_per_model_idx), figsize=(20,5))
sns.set(font_scale=1)

for idx, i in zip(sorted(best_per_model_idx), range(len(best_per_model_idx))):
    prec, rec = {}, {}

    for c in classes:
        prec[c], rec[c], _ = precision_recall_curve(y_test_bin[:, c], results.loc[idx, 'predict_proba'][:, c])
        axes[i].plot(rec[c], prec[c], lw=2, label='{}'.format(ticks(c,c+1)))
    
    title='{}-{}'.format(results.loc[idx, 'Model'], results.loc[idx, 'enc_ver'])
    axes[i].set_title(title, fontsize=20)
    axes[i].set_xlabel("Recall")
    axes[0].set_ylabel("Precision")
    axes[i].legend(loc="best")

plt.show()
