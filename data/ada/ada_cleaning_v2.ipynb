# %% [markdown]
# # EDA for Average Daily Attendance Data

# %% [markdown]
# ***Import libraries:***

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ***Data Reading:***

# %%
# read in the csv file
df_d = pd.read_csv('ada_district.csv')

print(df_d.info())
df_d.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1407 entries, 0 to 1406
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   County          1407 non-null   int64
#  1   County Name     1407 non-null   object
#  2   District        1407 non-null   int64
#  3   District Name   1407 non-null   object
#  4    2004-2005 ADA  1296 non-null   object
#  5    2005-2006 ADA  1279 non-null   object
#  6    2006-2007 ADA  1296 non-null   object
#  7   2007-2008 ADA   1284 non-null   object
#  8   2008-2009 ADA   1283 non-null   object
#  9    2009-2010 ADA  1285 non-null   object
#  10  2010-2011 ADA   1303 non-null   object
#  11   2011-2012 ADA  1254 non-null   object
#  12   2012-2013 ADA  1260 non-null   object
#  13   2013-2014 ADA  1257 non-null   object
#  14   2014-2015 ADA  1249 non-null   object
#  15   2015-2016 ADA  1238 non-null   object
#  16   2016-2017 ADA  1232 non-null   object
# ...

# %%
cols_old = df_d.columns.to_list()
cols_new = ['County #',
'County Name',
'District #',
'District Name',
'2004-2005 ADA',
'2005-2006 ADA',
'2006-2007 ADA',
'2007-2008 ADA',
'2008-2009 ADA',
'2009-2010 ADA',
'2010-2011 ADA',
'2011-2012 ADA',
'2012-2013 ADA',
'2013-2014 ADA',
'2014-2015 ADA',
'2015-2016 ADA',
'2016-2017 ADA',
'2017-2018 ADA',
'2018-2019 ADA',
'2019-2020 ADA',
'2020-2021 ADA']

df_d.rename(columns=dict(zip(cols_old, cols_new)), inplace=True)

# %%
df_d.replace(',', '', regex=True, inplace=True)
df_d[cols_new[4:]] = df_d[cols_new[4:]].astype('float')

# %%
cols_keep=['County #',
'District #',
'2018-2019 ADA',
'2019-2020 ADA',
'2020-2021 ADA']

df_d[cols_keep].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1407 entries, 0 to 1406
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   County #       1407 non-null   int64
#  1   District #     1407 non-null   int64
#  2   2018-2019 ADA  1230 non-null   float64
#  3   2019-2020 ADA  1230 non-null   float64
#  4   2020-2021 ADA  1233 non-null   float64
# dtypes: float64(3), int64(2)
# memory usage: 55.1 KB

# %%
temp=[c + ': ' + str(df_d[c].isna().sum()) for c in df_d[cols_keep] if df_d[c].isna().any()]
temp
# Out:
# ['2018-2019 ADA: 177', '2019-2020 ADA: 177', '2020-2021 ADA: 174']

# %%
df_d.to_csv('DATA_ADA_DISTRICT.csv', index = None)

# %%
# read in the csv file
df_c = pd.read_csv('ada_county.csv')

df_c.drop(columns = [' 2004-2005 ADA', \
                    ' 2005-2006 ADA', \
                    ' 2006-2007 ADA', \
                    '2007-2008 ADA', \
                    '2008-2009 ADA', \
                    ' 2009-2010 ADA', \
                    '2010-2011 ADA', \
                    ' 2011-2012 ADA', \
                    ' 2012-2013 ADA', \
                    ' 2013-2014 ADA', \
                    ' 2014-2015 ADA', \
                    ' 2015-2016 ADA', \
                    ' 2016-2017 ADA'], inplace = True)

df_c
# Out:
#      County      County Name  2017-2018 ADA  2018-2019 ADA  2019-2020 ADA  \
# 0         1  ANDERSON COUNTY       7,786.97       7,690.77       7,340.51
# 1         2   ANDREWS COUNTY       3,840.23       4,085.36       4,064.98
# 2         3  ANGELINA COUNTY      15,973.61      15,763.88      15,282.64
# 3         4   ARANSAS COUNTY       3,192.18       2,641.35       2,680.59
# 4         5    ARCHER COUNTY       1,806.48       1,839.82       1,826.43
# ..      ...              ...            ...            ...            ...
# 248     250      WOOD COUNTY       5,820.52       5,787.86       5,583.89
# 249     251    YOAKUM COUNTY       1,995.59       2,024.96       1,966.94
# 250     252     YOUNG COUNTY       3,062.38       3,098.99       2,859.72
# 251     253    ZAPATA COUNTY       3,077.73       3,117.64       2,933.07
# 252     254    ZAVALA COUNTY       2,195.63       2,213.47       2,081.81
#
#      2020-2021 ADA
# 0         7213.337
# 1         4068.126
# ...

# %%
columns = ['County', 'County Name', 'County #', 'Public Health Region', 'Health Service Region']

cc = pd.read_csv('county_conversion.csv', names = columns, header = 0)

cc.drop(columns = ['Public Health Region', 'Health Service Region', 'County Name'], inplace = True)

cc
# Out:
#      County  County #
# 0         1     48001
# 1         2     48003
# 2         3     48005
# 3         4     48007
# 4         5     48009
# ..      ...       ...
# 249     250     48499
# 250     251     48501
# 251     252     48503
# 252     253     48505
# 253     254     48507
#
# [254 rows x 2 columns]

# %%
df_c = df_c.merge(cc, how = "inner", on = "County")

# %%
df_c
# Out:
#      County      County Name  2017-2018 ADA  2018-2019 ADA  2019-2020 ADA  \
# 0         1  ANDERSON COUNTY       7,786.97       7,690.77       7,340.51
# 1         2   ANDREWS COUNTY       3,840.23       4,085.36       4,064.98
# 2         3  ANGELINA COUNTY      15,973.61      15,763.88      15,282.64
# 3         4   ARANSAS COUNTY       3,192.18       2,641.35       2,680.59
# 4         5    ARCHER COUNTY       1,806.48       1,839.82       1,826.43
# ..      ...              ...            ...            ...            ...
# 248     250      WOOD COUNTY       5,820.52       5,787.86       5,583.89
# 249     251    YOAKUM COUNTY       1,995.59       2,024.96       1,966.94
# 250     252     YOUNG COUNTY       3,062.38       3,098.99       2,859.72
# 251     253    ZAPATA COUNTY       3,077.73       3,117.64       2,933.07
# 252     254    ZAVALA COUNTY       2,195.63       2,213.47       2,081.81
#
#      2020-2021 ADA  County #
# 0         7213.337     48001
# ...

# %%
df_c.to_csv('DATA_ADA_COUNTY.csv', index = None)
